# %%
import array

# %%
arr = array.array('i',[1,2,3,4,5])

# %%
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math

# %%
print(math.sqrt(144))
# Out:
# 12.0

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
import random

# %%
print(random.randint(1,10))
# Out:
# 7

# %%
# it will produce a number randomly b/w 1 to 10

# %%
print(random.choice(["chandru",'lokesh','kadhirvel']))
# Out:
# lokesh

# %%
import os

# %%
# it uses file and directory access

# %%
print(os.getcwd())
# Out:
# C:\Users\CHANDRU DEIVANAYAGAN\OneDrive\Desktop\Data Science\Python\module

# %%
os.mkdir("test_dir")

# %%
## high level operation on files and collection of file

# %%
import shutil

# %%
shutil.copyfile("source.txt","destination.txt")
# Out:
# 'destination.txt'

# %%
# data serialization
