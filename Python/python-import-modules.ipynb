# %%
import math

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.cbrt(1000)
# Out:
# 10.0

# %%
print(pi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(pi)
#
# NameError: name 'pi' is not defined

# %%
from math import sqrt,pi

# %%
print(pi)
# Out:
# 3.141592653589793

# %%
import numpy as np

# %%
# pip install numpy from the terminal, if you are using vscode

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *

# %%
sqrt(100)
# Out:
# 10.0

# %%
cbrt(343)
# Out:
# 7.0

# %%
pi
# Out:
# 3.141592653589793

# %%
print(pi)
# Out:
# 3.141592653589793

# %%
from module.math import add

# %%
add(5646456,5446845)
# Out:
# 11093301
