# %%
import os
cwd = os.getcwd()
print(f"Current working directory is {cwd}")
# Out:
# Current working directory is C:\Users\CHANDRU DEIVANAYAGAN\OneDrive\Desktop\Data Science\Python\file-handling

# %%
# create a directory

# %%
new_directory = "Package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created.")
# Out:
# Directory 'Package' created.

# %%
## list all the files and directories

# %%
items = os.listdir('.')
print(items)
# Out:
# ['.ipynb_checkpoints', 'destination.txt', 'example.bin', 'example.txt', 'example2.txt', 'file-operation-python.ipynb', 'Package', 'working-with-filepath.ipynb']

# %%
### Joining paths

# %%
dir_name = "Folder"
file_name = "File.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# C:\Users\CHANDRU DEIVANAYAGAN\OneDrive\Desktop\Data Science\Python\file-handling\Folder\File.txt

# %%
path = "example.txt"
if os.path.exists(path):
    print(f"The path '{path}' is exists")
else:
    print(f"The path '{path}' does not exists")
# Out:
# The path 'example.txt' is exists

# %%
# checking if a path is a file or directory?

# %%
import os

path = 'example.txt'

if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The path 'example.txt' is a file.

# %%
## getting the absolute path

# %%
relative_path = "example.txt"
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# C:\Users\CHANDRU DEIVANAYAGAN\OneDrive\Desktop\Data Science\Python\file-handling\example.txt
