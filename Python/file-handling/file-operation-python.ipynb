# %%
## Read a whole file:

with open("example.txt",'r') as file:
    content = file.read()
    print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 ## Read a whole file:
# ----> 3 with open("example.txt",'r') as file:
#       4     content = file.read()
#       5     print(content)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %%
## Read a whole file:

with open("example.txt",'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello how are you sweety?
# I am good
# where are you
# come to my home.

# %%
## Read a file line by line:

with open("example.txt",'r') as file:
    for line in file:
        print(line)
# Out:
# Hello how are you sweety?
#
# I am good
#
# where are you
#
# come to my home.

# %%
## Read a file line by line:

with open("example.txt",'r') as file:
    for line in file:
        print(line.strip()) ## strip() removes the leading and trailing spaces.
# Out:
# Hello chandru!!!!
# this is a new line...Hello chandru!!!!
# this is a new line...Append operation takes place in this file

# %%
## writing a file: --- overwriting

with open ("example.txt",'w') as file:
    file.write("Hello chandru!!!!\n")
    file.write("this is a new line...")

# %%
## writing a file: --- with out overwriting

with open ("example.txt",'a') as file:
    file.write("Hello chandru!!!!\n")
    file.write("this is a new line...")
    file.write("Append operation takes place in this file\n")

# %%
## writing list of line to a file:

lines = ['Chandru\n','kadhirvel\n','lokesh\n','Boominath\n']
with open("example.txt",'a') as file:
    file.writelines(lines)

# %%
## Binary files

# writing to a binary file

data = b'\x00\x01\x02\x03\x04'
with open("example.bin",'wb') as file:
    file.write(data)

# %%
# reading the binary file

with open("example.bin",'rb') as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
# practical examples

# %%
## read the content from a source text file and write to a destination text file

# %%
with open("example.txt",'r') as source_file:
    content = source_file.read()

with open("destination.txt",'w') as destination_file:
    destination_file.write(content)

# %%
## read the text file and count the number of lines, words and characters.

# %%
with open("example.txt",'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello chandru!!!!
# this is a new line...Hello chandru!!!!
# this is a new line...Append operation takes place in this file
# Hello chandru!!!!
# this is a new line...Append operation takes place in this file
# Chandru
# kadhirvel
# lokesh
# Boominath

# %%
def count_text_file(file_path):
    with open(file_path,'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    return line_count,word_count,char_count

file_path = "example.txt"
lines,words,characters = count_text_file(file_path)
print(f"Lines: {lines}, Words: {words}, Characters: {characters}")
# Out:
# Lines: 9, Words: 36, Characters: 236

# %%
## writing and reading the file

# %%
with open("example2.txt","w+") as file:
    file.write("Hello chandru\n")
    file.write("Hello welcome home\n")

    # move the file cursor to the beginning

    file.seek(0)

    # read the content of the file
    content = file.read()
    print(content)
# Out:
# Hello chandru
# Hello welcome home
