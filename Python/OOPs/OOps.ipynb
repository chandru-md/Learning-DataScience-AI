# %% [markdown]
# class Student:
#
#     def say_hello(self):
#         print("Hello Student")

# %% [markdown]
# s1 = Student()

# %% [markdown]
# s1.say_hello()

# %%
class Student:

    def say_hello(self,fname,age):
        self.fname = fname
        self.age = age
        
        #print("Hello Student")

    def display(self):
        print(f"Name:{self.fname}, Age:{self.age}")

# %%
s1 = Student(fname="Chandru",age=23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s1 = Student(fname="Chandru",age=23)
#
# TypeError: Student() takes no arguments
