# %% [markdown]
# ## STRING FUNCTIONS

# %%
course = "python programming"

# %%
type(course)
# Out:
# str

# %%
course.capitalize()
# Out:
# 'Python programming'

# %%
course = "PyThoN ProGraMmiNg"

# %%
course.casefold()
# Out:
# 'python programming'

# %%
course
# Out:
# 'python programming'

# %%
course.count('p')
# Out:
# 2

# %%
course.encode()
# Out:
# b'python programming'

# %%
course.endswith('mming')
# Out:
# True

# %%
course.endswith('ng')
# Out:
# True

# %%
course.find('m')
# Out:
# 13

# %%
course.index('n')
# Out:
# 5

# %%
course.isalnum()
# Out:
# False

# %%
name = 'data'

# %%
course.isalpha()
# Out:
# True

# %%
name.isalpha()
# Out:
# True

# %%
course.isascii()
# Out:
# True

# %%
num = 0.45

# %%
num.is_integer()
# Out:
# False

# %%
num= 108

# %%
name = 'Chandru'

# %%
name.islower()
# Out:
# False

# %%
name.isidentifier()
# Out:
# True

# %%
name.islower()
# Out:
# False

# %%
name.isupper()
# Out:
# False

# %%
name.isprintable()
# Out:
# True

# %%
name.istitle()
# Out:
# True

# %%
name1 = "    chandru"

# %%
name2 = "chandru    "

# %%
name3 = "    chandru    "

# %%
name.upper()
# Out:
# 'CHANDRU'

# %%
name.lower()
# Out:
# 'chandru'

# %%
name.title()
# Out:
# 'Chandru'

# %%
name1.lstrip()
# Out:
# 'chandru'

# %%
name2.rstrip()
# Out:
# 'chandru'

# %%
name.strip()
# Out:
# 'chandru'

# %%
name.title()
# Out:
# 'Chandru'

# %%
name.swapcase()
# Out:
# 'CHANDRU'

# %%
name.splitlines()
# Out:
# ['chandru']

# %%
name.split()
# Out:
# ['chandru']

# %%
course.split()
# Out:
# ['python', 'programming']

# %%
course.splitlines()
# Out:
# ['python programming']

# %%
course.startswith('py')
# Out:
# True

# %%
name.partition('a')
# Out:
# ('ch', 'a', 'ndru')

# %%
course.partition('prog')
# Out:
# ('python ', 'prog', 'ramming')

# %%
type(name)
# Out:
# str

# %%
course.isnumeric()
# Out:
# False

# %%
name.isnumeric()
# Out:
# False

# %%
tech = "Data Science"

# %%
tech.lower()
# Out:
# 'data science'

# %%
tech.upper()
# Out:
# 'DATA SCIENCE'

# %%
tech.strip()
# Out:
# 'Data Science'

# %%
tech.capitalize()
# Out:
# 'Data science'

# %%
tech.title()
# Out:
# 'Data Science'

# %%
len(tech)
# Out:
# 12

# %%
tech.find('Science')
# Out:
# 5

# %%
tech.count('a')
# Out:
# 2

# %%
tech.startswith('Da')
# Out:
# True

# %%
tech.endswith("ce")
# Out:
# True

# %%
tech.replace('Science','Scientist')
# Out:
# 'Data Scientist'

# %%
tech.split()
# Out:
# ['Data', 'Science']

# %%
frds = 'Apple','Microsoft','Amazon','X','Black Rock'

# %%
frds
# Out:
# ('Apple', 'Microsoft', 'Amazon', 'X', 'Black Rock')

# %%
type(frds)
# Out:
# tuple

# %%
frds = "Apple Microsoft Amazon X BlackRock"

# %%
frds=frds.split()
frds
# Out:
# ['Apple', 'Microsoft', 'Amazon', 'X', 'BlackRock']

# %%
frds = '-'.join(frds)

# %%
frds
# Out:
# 'Apple-Microsoft-Amazon-X-BlackRock'

# %%
company = "BlackRock"

print("My friend is working in {}".format(company))
# Out:
# My friend is working in BlackRock

# %%
print(f"My friend is working in {company}.")
# Out:
# My friend is working in BlackRock.
