# %% [markdown]
# ### getting and understanding the data

# %%
import pandas as pd

# %%
pd.read_csv(filepath_or_buffer="data.tsv.txt",sep='@')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
order_details = pd.read_csv(filepath_or_buffer="data.tsv.txt",sep='@')

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### perform initial analysis

# %%
order_details.shape
# Out:
# (4622, 5)

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_details.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
order_details.isnull().sum()  #chain of functions
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %% [markdown]
# ### ROWS - OBSERVATIONS, COLUMNS - FEATURES/PARAMETERS

# %%
order_details.describe(include=None)
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
order_details.describe(include="all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# ### find out the sold items in the restaurants

# %%
order_details.nunique()
# Out:
# order_id              1834
# quantity                 9
# item_name               50
# choice_description    1043
# item_price              78
# dtype: int64

# %%
order_details["item_name"].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
print(order_details["item_name"].unique())
# Out:
# ['Chips and Fresh Tomato Salsa' 'Izze' 'Nantucket Nectar'
#  'Chips and Tomatillo-Green Chili Salsa' 'Chicken Bowl' 'Side of Chips'
#  'Steak Burrito' 'Steak Soft Tacos' 'Chips and Guacamole'
#  'Chicken Crispy Tacos' 'Chicken Soft Tacos' 'Chicken Burrito'
#  'Canned Soda' 'Barbacoa Burrito' 'Carnitas Burrito' 'Carnitas Bowl'
#  'Bottled Water' 'Chips and Tomatillo Green Chili Salsa' 'Barbacoa Bowl'
#  'Chips' 'Chicken Salad Bowl' 'Steak Bowl' 'Barbacoa Soft Tacos'
#  'Veggie Burrito' 'Veggie Bowl' 'Steak Crispy Tacos'
#  'Chips and Tomatillo Red Chili Salsa' 'Barbacoa Crispy Tacos'
#  'Veggie Salad Bowl' 'Chips and Roasted Chili-Corn Salsa'
#  'Chips and Roasted Chili Corn Salsa' 'Carnitas Soft Tacos'
#  'Chicken Salad' 'Canned Soft Drink' 'Steak Salad Bowl'
#  '6 Pack Soft Drink' 'Chips and Tomatillo-Red Chili Salsa' 'Bowl'
#  'Burrito' 'Crispy Tacos' 'Carnitas Crispy Tacos' 'Steak Salad'
#  'Chips and Mild Fresh Tomato Salsa' 'Veggie Soft Tacos'
# ...

# %% [markdown]
# ### list of top 5 selling items

# %%
order_details.groupby(by="item_name")["quantity"].sum()
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# ...

# %%
order_details.groupby(by="item_name")["quantity"].sum().sort_values(ascending=False).head(11)
# Out:
# item_name
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chips and Guacamole             506
# Steak Burrito                   386
# Canned Soft Drink               351
# Chips                           230
# Steak Bowl                      221
# Bottled Water                   211
# Chips and Fresh Tomato Salsa    130
# Canned Soda                     126
# Chicken Salad Bowl              123
# Name: quantity, dtype: int64

# %%
order_details.value_counts("item_name").head(11)
# Out:
# item_name
# Chicken Bowl                    726
# Chicken Burrito                 553
# Chips and Guacamole             479
# Steak Burrito                   368
# Canned Soft Drink               301
# Chips                           211
# Steak Bowl                      211
# Bottled Water                   162
# Chicken Soft Tacos              115
# Chicken Salad Bowl              110
# Chips and Fresh Tomato Salsa    110
# Name: count, dtype: int64

# %% [markdown]
# ### list of least 5 selling items

# %%
order_details.value_counts("item_name").tail(11)
# Out:
# item_name
# Veggie Soft Tacos                    7
# Burrito                              6
# Carnitas Salad Bowl                  6
# Veggie Salad                         6
# Steak Salad                          4
# Salad                                2
# Bowl                                 2
# Crispy Tacos                         2
# Carnitas Salad                       1
# Chips and Mild Fresh Tomato Salsa    1
# Veggie Crispy Tacos                  1
# Name: count, dtype: int64

# %% [markdown]
# ### DATA CLEANING

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_details.shape
# Out:
# (4622, 5)

# %%
order_details["item_price"]
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
order_details["item_price"].str.replace("$","").astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
# Chain of methods

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
order_details["item_price"] = order_details["item_price"].str.replace("$","").astype(float)

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
order_details.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
order_details.describe()
# Out:
#           order_id     quantity   item_price
# count  4622.000000  4622.000000  4622.000000
# mean    927.254868     1.075725     7.464336
# std     528.890796     0.410186     4.245557
# min       1.000000     1.000000     1.090000
# 25%     477.250000     1.000000     3.390000
# 50%     926.000000     1.000000     8.750000
# 75%    1393.000000     1.000000     9.250000
# max    1834.000000    15.000000    44.250000

# %% [markdown]
# ##### TASKS

# %%
order_details.groupby(by="item_name")["item_price"].sum().head()
# Out:
# item_name
# 6 Pack Soft Drink        356.95
# Barbacoa Bowl            672.36
# Barbacoa Burrito         894.75
# Barbacoa Crispy Tacos    120.21
# Barbacoa Salad Bowl      106.40
# Name: item_price, dtype: float64

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
order_details.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
order_details["Revenue"] = order_details["item_price"] * order_details["quantity"]

# %%
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  Revenue
# 0                                                   NaN        2.39     2.39
# ...

# %%
order_details["Revenue"].value_counts().head()
# Out:
# Revenue
# 8.75     730
# 11.25    528
# 9.25     398
# 4.45     349
# 8.49     311
# Name: count, dtype: int64

# %%
order_details.groupby(by="item_name")["Revenue"].sum().sort_values(ascending=False).head(11)
# Out:
# item_name
# Chicken Bowl                    8044.63
# Chicken Burrito                 6387.06
# Steak Burrito                   4236.13
# Steak Bowl                      2479.81
# Chips and Guacamole             2475.62
# Chicken Salad Bowl              1506.25
# Chicken Soft Tacos              1199.01
# Chips and Fresh Tomato Salsa    1033.96
# Veggie Burrito                  1002.27
# Veggie Bowl                      901.95
# Barbacoa Burrito                 894.75
# Name: Revenue, dtype: float64

# %% [markdown]
# ### PANDAS DATA STRUCTURE

# %% [markdown]
# #### SERIES

# %%
pd.Series(data=[1,2,3.14,4,5.5,"$6"])
# Out:
# 0       1
# 1       2
# 2    3.14
# 3       4
# 4     5.5
# 5      $6
# dtype: object

# %%
pd.DataFrame(data=[1,2,3.14,4,5.5,"$6"])
# Out:
#       0
# 0     1
# 1     2
# 2  3.14
# 3     4
# 4   5.5
# 5    $6

# %% [markdown]
# #### DATAFRAME

# %%
studentmarks = {"Names":["Chandru","Boominath","Lokesh","Razeeth","Kadhirvel"],"Maths":[99,100,99,89,80],
                "Science":[90,95,92,90,100],"English":[90,99,100,67,89],"Tamil":[99,89,80,91,99],
                "Social Science":[99,98,98,99,100]}
pd.DataFrame(data=studentmarks)
# Out:
#        Names  Maths  Science  English  Tamil  Social Science
# 0    Chandru     99       90       90     99              99
# 1  Boominath    100       95       99     89              98
# 2     Lokesh     99       92      100     80              98
# 3    Razeeth     89       90       67     91              99
# 4  Kadhirvel     80      100       89     99             100

# %%
# TASK
# 1. meaningful series
# 2. meaningful dataframe - dictionary 5x6

# %% [markdown]
# #### FILTER SELECTING AND SORTING

# %%
euro_2012 = pd.read_csv(filepath_or_buffer="Euro_2012_stats_TEAM.csv")

# %%
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012.dtypes
# Out:
# Team                           object
# Goals                           int64
# Shots on target                 int64
# Shots off target                int64
# Shooting Accuracy              object
# % Goals-to-shots               object
# Total shots (inc. Blocked)      int64
# Hit Woodwork                    int64
# Penalty goals                   int64
# Penalties not scored            int64
# Headed goals                    int64
# Passes                          int64
# Passes completed                int64
# Passing Accuracy               object
# Touches                         int64
# Crosses                         int64
# Dribbles                        int64
# Corners Taken                   int64
# Tackles                         int64
# Clearances                      int64
# Interceptions                   int64
# Clearances off line           float64
# Clean Sheets                    int64
# Blocks                          int64
# Goals conceded                  int64
# ...

# %%
euro_2012.shape
# Out:
# (16, 35)

# %%
euro_2012.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
pd.set_option("display.max_columns",None) #NO need education purpose

# %%
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
filtered_euro_data = euro_2012[["Team","Goals","Yellow Cards","Red Cards"]]

# %%
filtered_euro_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
filtered_euro_data["Yellow Cards"]
# Out:
# 0      9
# 1      7
# 2      4
# 3      5
# 4      6
# 5      4
# 6      9
# 7     16
# 8      5
# 9      7
# 10    12
# 11     6
# 12     6
# 13    11
# 14     7
# 15     5
# Name: Yellow Cards, dtype: int64

# %%
# these are the top 5 yellow cards team

# %%
filtered_euro_data.sort_values(by="Yellow Cards",ascending=False).head()
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0
# 0    Croatia      4             9          0
# 6     Greece      5             9          1

# %%
filtered_euro_data.sort_values(by="Red Cards",ascending=False).head()
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1
# 0               Croatia      4             9          0
# 3               England      5             5          0

# %%
filtered_euro_data["Red Cards"] == 1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Red Cards, dtype: bool

# %%
# list the teams which has got red cards

# %%
filtered_euro_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %%
filtered_euro_data[filtered_euro_data["Red Cards"] == 1]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %%
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012[["Team","Goals","Yellow Cards","Red Cards"]]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %% [markdown]
# ##### FILTERING and column selecting method

# %%
filtered_euro_data
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 0               Croatia      4             9          0
# 1        Czech Republic      4             7          0
# 2               Denmark      4             4          0
# 3               England      5             5          0
# 4                France      3             6          0
# 5               Germany     10             4          0
# 6                Greece      5             9          1
# 7                 Italy      6            16          0
# 8           Netherlands      2             5          0
# 9                Poland      2             7          1
# 10             Portugal      6            12          0
# 11  Republic of Ireland      1             6          1
# 12               Russia      5             6          0
# 13                Spain     12            11          0
# 14               Sweden      5             7          0
# 15              Ukraine      2             5          0

# %% [markdown]
# ##### SORTING

# %%
filtered_euro_data["Yellow Cards"].value_counts()
# Out:
# Yellow Cards
# 7     3
# 5     3
# 6     3
# 9     2
# 4     2
# 16    1
# 12    1
# 11    1
# Name: count, dtype: int64

# %%
filtered_euro_data["Red Cards"].value_counts()
# Out:
# Red Cards
# 0    13
# 1     3
# Name: count, dtype: int64

# %%
filtered_euro_data.sort_values(by="Yellow Cards",ascending=False)
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 7                 Italy      6            16          0
# 10             Portugal      6            12          0
# 13                Spain     12            11          0
# 0               Croatia      4             9          0
# 6                Greece      5             9          1
# 14               Sweden      5             7          0
# 9                Poland      2             7          1
# 1        Czech Republic      4             7          0
# 12               Russia      5             6          0
# 11  Republic of Ireland      1             6          1
# 4                France      3             6          0
# 3               England      5             5          0
# 8           Netherlands      2             5          0
# 15              Ukraine      2             5          0
# 5               Germany     10             4          0
# 2               Denmark      4             4          0

# %%
filtered_euro_data.sort_values(by="Yellow Cards",ascending=False).head(5)
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0
# 0    Croatia      4             9          0
# 6     Greece      5             9          1

# %%
filtered_euro_data.sort_values(by="Red Cards",ascending=False).head(5)
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1
# 0               Croatia      4             9          0
# 3               England      5             5          0

# %%
filtered_euro_data["Red Cards"] == 1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# Name: Red Cards, dtype: bool

# %%
filtered_euro_data[filtered_euro_data["Red Cards"]==1]
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %%
filtered_euro_data[filtered_euro_data["Yellow Cards"]>=8]
# Out:
#         Team  Goals  Yellow Cards  Red Cards
# 0    Croatia      4             9          0
# 6     Greece      5             9          1
# 7      Italy      6            16          0
# 10  Portugal      6            12          0
# 13     Spain     12            11          0

# %%
filtered_euro_data[filtered_euro_data["Yellow Cards"]<5]
# Out:
#       Team  Goals  Yellow Cards  Red Cards
# 2  Denmark      4             4          0
# 5  Germany     10             4          0

# %% [markdown]
# #### HANDLING MISSING VALUES

# %%
employee_data = pd.read_csv("employee_data.csv")

# %%
employee_data.head()
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %% [markdown]
# #### Level -1 of Data cleaning

# %%
# Step-1 call to my client, check with him if he can give the right data.
# incase client is asking us to perform the data cleaning operations.

# %%
# ALways recommended, remove duplicate records.

# %%
# step-1 remove duplicate records

# %%
employee_data.drop_duplicates()
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %%
employee_data.drop_duplicates(inplace=True)

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %%
# step-2 find out the null entries

# %%
employee_data.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        1
# Join_Date     0
# dtype: int64

# %%
employee_data.dropna(inplace=True)

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
employee_data.shape
# Out:
# (4, 5)

# %%
# step-3 record in an document

# %%
# get approval

# %%
step4 = """ Client gave totally 7 observations out of which 3 entrirs are removed because those records do not have complete information.
    Send this to client and get the approval to proceed for model building or model training."""

# %%
employee_data
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
employee_data.isna().sum()
# Out:
# Name          0
# Age           0
# Department    0
# Salary        0
# Join_Date     0
# dtype: int64

# %% [markdown]
# #### Level-2 of Data Cleaning

# %%
# pd.read_csv("") # you can't import multiple sheets if its one csv file

# %%
# pd.read_excel("") # you can import multiple sheets

# %%
pd.read_excel("employee_data.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
# drop duplicates

# %%
#identify null entries

# %%
# go for best imputation

# %%
# compare with all departments

# %%
employee_added_details = pd.read_excel("employee_data.xlsx",sheet_name="more_employee_data")

# %%
employee_added_details
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech      NaN 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 8       Kuppusamy  28.0        Ops      NaN 2021-05-21
# 9           Ajesh  28.0    Support      NaN 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 11  Jagadheeswari  28.0    IT Tech      NaN        NaT
# 12           Mani  28.0        Ops      NaN 2021-05-21

# %%
# step-1

# %%
employee_added_details.drop_duplicates(inplace=True)

# %%
employee_added_details.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# dtype: bool

# %%
employee_added_details
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech      NaN 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 8       Kuppusamy  28.0        Ops      NaN 2021-05-21
# 9           Ajesh  28.0    Support      NaN 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 11  Jagadheeswari  28.0    IT Tech      NaN        NaT
# 12           Mani  28.0        Ops      NaN 2021-05-21

# %%
# step-2 Identify null entries

# %%
employee_added_details.isna().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        6
# Join_Date     1
# dtype: int64

# %%
#step-3

# %%
#Impute - best imputation

# %%
employee_added_details["Department"].unique()
# Out:
# array(['Ops', 'IT Tech', 'Support'], dtype=object)

# %%
employee_added_details[employee_added_details["Department"] == "Support"]
# Out:
#       Name   Age Department   Salary  Join_Date
# 2  Mathiew   NaN    Support  58000.0 2025-01-15
# 4    Kevin  28.0    Support  61000.0 2024-07-30
# 5    Navin  35.0    Support  72000.0 2023-08-19
# 9    Ajesh  28.0    Support      NaN 2024-07-30

# %%
employee_added_details[employee_added_details["Department"] == "IT Tech"]
# Out:
#              Name   Age Department   Salary  Join_Date
# 1           Nasir  31.0    IT Tech      NaN 2020-11-12
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 11  Jagadheeswari  28.0    IT Tech      NaN        NaT

# %%
employee_added_details[employee_added_details["Department"] == "Ops"]
# Out:
#          Name   Age Department   Salary  Join_Date
# 0      Rajesh  29.0        Ops  60000.0 2023-05-21
# 3     Gilbert  29.0        Ops  60000.0 2021-05-21
# 8   Kuppusamy  28.0        Ops      NaN 2021-05-21
# 12       Mani  28.0        Ops      NaN 2021-05-21

# %%
# TASK- Impute the relevant values in the salary column whether it's Nan based on Department Filtering

# %%
#Impute MAthew's age as 27

# %%
employee_added_details
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech      NaN 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 8       Kuppusamy  28.0        Ops      NaN 2021-05-21
# 9           Ajesh  28.0    Support      NaN 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 11  Jagadheeswari  28.0    IT Tech      NaN        NaT
# 12           Mani  28.0        Ops      NaN 2021-05-21

# %%
employee_added_details
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech      NaN 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech      NaN 2020-11-12
# 8       Kuppusamy  28.0        Ops      NaN 2021-05-21
# 9           Ajesh  28.0    Support      NaN 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 11  Jagadheeswari  28.0    IT Tech      NaN        NaT
# 12           Mani  28.0        Ops      NaN 2021-05-21

# %%
employee_added_details[(employee_added_details["Department"] == "Support") & (employee_added_details["Salary"].isna())]
# Out:
#     Name   Age Department  Salary  Join_Date
# 9  Ajesh  28.0    Support     NaN 2024-07-30

# %%
employee_added_details["Salary"]=="Nan"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# Name: Salary, dtype: bool

# %%
# task-1

# %%
employee_added_details["Salary"] = employee_added_details.groupby(by="Department")["Salary"].transform(lambda x: x.fillna(x.median()))

# %%
employee_added_details
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech  63500.0 2020-11-12
# 2         Mathiew   NaN    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech  63500.0 2020-11-12
# 8       Kuppusamy  28.0        Ops  60000.0 2021-05-21
# 9           Ajesh  28.0    Support  61000.0 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 11  Jagadheeswari  28.0    IT Tech  63500.0        NaT
# 12           Mani  28.0        Ops  60000.0 2021-05-21

# %%
# task-2

# %%
employee_added_details["Age"] = employee_added_details.groupby(by="Department")["Age"].transform(lambda x: x.fillna(x.median()))

# %%
employee_added_details
# Out:
#              Name   Age Department   Salary  Join_Date
# 0          Rajesh  29.0        Ops  60000.0 2023-05-21
# 1           Nasir  31.0    IT Tech  63500.0 2020-11-12
# 2         Mathiew  28.0    Support  58000.0 2025-01-15
# 3         Gilbert  29.0        Ops  60000.0 2021-05-21
# 4           Kevin  28.0    Support  61000.0 2024-07-30
# 5           Navin  35.0    Support  72000.0 2023-08-19
# 6             NaN  40.0    IT Tech  64000.0 2022-09-10
# 7          Roshan  31.0    IT Tech  63500.0 2020-11-12
# 8       Kuppusamy  28.0        Ops  60000.0 2021-05-21
# 9           Ajesh  28.0    Support  61000.0 2024-07-30
# 10           Diya  31.0    IT Tech  63000.0 2020-11-12
# 11  Jagadheeswari  28.0    IT Tech  63500.0        NaT
# 12           Mani  28.0        Ops  60000.0 2021-05-21
