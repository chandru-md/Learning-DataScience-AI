# %% [markdown]
# ### BUILT IN DATA STRUCTURE

# %%
# TO COLLECT MULTIPLE DATA IN A STRUCTURE

# %%
# LIST SET TUPLE DICTIONARY

# %% [markdown]
# #### LIST

# %%
student_marks = 41,85,96,74,100,98

# %%
student_marks
# Out:
# (41, 85, 96, 74, 100, 98)

# %%
type(student_marks)
# Out:
# tuple

# %%
empty_cart = []

# %%
type(empty_cart)
# Out:
# list

# %%
items_to_buy = ["apple","orange","red-banana","pomagranate"]
items_to_buy
# Out:
# ['apple', 'orange', 'red-banana', 'pomagranate']

# %%
type(items_to_buy)
# Out:
# list

# %%
items_to_buy = ["apple","orange","Grapes","red-banana","pomagranate",3.14]

# %%
items_to_buy
# Out:
# ['apple', 'orange', 'Grapes', 'red-banana', 'pomagranate', 3.14]

# %%
items_to_buy[0]
# Out:
# 'apple'

# %%
items_to_buy[-1]
# Out:
# 3.14

# %%
items_to_buy[2]
# Out:
# 'red-banana'

# %%
items_to_buy[-4]
# Out:
# 'orange'

# %%
len(items_to_buy)
# Out:
# 5

# %%
items_to_buy[3]
# Out:
# 'pomagranate'

# %%
items_to_buy[4]
# Out:
# 3.14

# %%
items_to_buy[-5]
# Out:
# 'apple'

# %%
items_to_buy[0:-1]
# Out:
# ['apple', 'orange', 'Grapes', 'red-banana', 'pomagranate']

# %%
items_to_buy[2:]
# Out:
# ['Grapes', 'red-banana', 'pomagranate', 3.14]

# %%
items_to_buy[:]
# Out:
# ['apple', 'orange', 'Grapes', 'red-banana', 'pomagranate', 3.14]

# %%
items_to_buy[-4:-2]
# Out:
# ['Grapes', 'red-banana']

# %%
items_to_buy.append("Dragon Fruit")

# %%
items_to_buy[1]="Avacoda"

# %%
items_to_buy.count("Avacoda")
# Out:
# 1

# %%
items_to_buy
# Out:
# ['apple',
#  'Avacoda',
#  'Grapes',
#  'red-banana',
#  'pomagranate',
#  3.14,
#  'Dragon Fruit']

# %%
items_to_buy.index('apple')
# Out:
# 0

# %% [markdown]
# ### SET

# %%
empty_set = set()

# %%
type(empty_set)
# Out:
# set

# %%
items_to_buy_2 = {"apple","orange","Grapes","red-banana","pomagranate",3.14}

# %%
type(items_to_buy_2)
# Out:
# set

# %%
items_to_buy_2[0] = "Banana"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 items_to_buy_2[0] = "Banana"
#
# TypeError: 'set' object does not support item assignment

# %%
items_to_buy_2
# Out:
# {3.14, 'Grapes', 'apple', 'orange', 'pomagranate', 'red-banana'}

# %%
items_to_buy_2.add("Banana")

# %%
items_to_buy_2
# Out:
# {3.14, 'Banana', 'Grapes', 'apple', 'orange', 'pomagranate', 'red-banana'}

# %%
items_to_buy_2.discard("apple")

# %%
items_to_buy_2
# Out:
# {3.14, 'Banana', 'Grapes', 'orange', 'pomagranate', 'red-banana'}

# %% [markdown]
# ### TUPLE

# %%
empty_tuple = ()

# %%
type(empty_tuple)
# Out:
# tuple

# %%
items_to_buy_3 = ("apple","orange","Grapes","red-banana","pomagranate",3.14,'apple')

# %%
type(items_to_buy_3)
# Out:
# tuple

# %%
items_to_buy_3
# Out:
# ('apple', 'orange', 'Grapes', 'red-banana', 'pomagranate', 3.14, 'apple')

# %%
items_to_buy_3[0] = "green"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 items_to_buy_3[0] = "green"
#
# TypeError: 'tuple' object does not support item assignment

# %%
items_to_buy_3.count(3.14)
# Out:
# 1

# %%
items_to_buy_3.index("pomagranate")
# Out:
# 4

# %% [markdown]
# ### DICTIONARY

# %%
# its a key-value pair

# %%
empty_dict_new = {}

# %%
type(empty_dict_new)
# Out:
# dict

# %%
studentmarks = {"Maths":99,"Science":90,"English":90,"Tamil":99,"Social Science":99}

# %%
items = {"apple":2,"Orange":3,"Dates":6,"Avacoda":3}

# %%
items
# Out:
# {'apple': 2, 'Orange': 3, 'Dates': 6, 'Avacoda': 3}

# %%
items.keys()
# Out:
# dict_keys(['apple', 'Orange', 'Dates', 'Avacoda'])

# %%
items.values()
# Out:
# dict_values([2, 3, 6, 3])

# %%
items.items()
# Out:
# dict_items([('apple', 2), ('Orange', 3), ('Dates', 6), ('Avacoda', 3)])

# %%
import pandas as pd

# %%
pd.DataFrame(data=items,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 pd.DataFrame(data=items)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
studentmarks = {"Names":["Chandru","Boominath","Lokesh","Razeeth","Kadhirvel"],"Maths":[99,100,99,89,80],
                "Science":[90,95,92,90,100],"English":[90,99,100,67,89],"Tamil":[99,89,80,91,99],
                "Social Science":[99,98,98,99,100]}
pd.DataFrame(data=studentmarks)
# Out:
#        Names  Maths  Science  English  Tamil  Social Science
# 0    Chandru     99       90       90     99              99
# 1  Boominath    100       95       99     89              98
# 2     Lokesh     99       92      100     80              98
# 3    Razeeth     89       90       67     91              99
# 4  Kadhirvel     80      100       89     99             100

# %% [markdown]
# ### Task-3

# %%
import pandas as pd

# %%
# 3 different data frames by own

# %%
friends = pd.DataFrame({"Employee":["Boomi","Lokesh","Kadhirvel","Razeeth"],
                       "Department":["CEO","CTO","CFO","COO"]
                       })

# %%
friends
# Out:
#     Employee Department
# 0      Boomi        CEO
# 1     Lokesh        CTO
# 2  Kadhirvel        CFO
# 3    Razeeth        COO

# %%
stars = pd.DataFrame(
    {
        "Name":["Vijay","Ajith","Vikram","Surya","John","Nasir"],
        "Expert":["dancing","racing","Acting","Acting","Coaching","Teaching"],
        "location":["India","USA","UAE","UK","RUSSIA","JAPAN"]
    }
)

# %%
stars
# Out:
#      Name    Expert location
# 0   Vijay   dancing    India
# 1   Ajith    racing      USA
# 2  Vikram    Acting      UAE
# 3   Surya    Acting       UK
# 4    John  Coaching   RUSSIA
# 5   Nasir  Teaching    JAPAN

# %%
my_team = pd.DataFrame(
    {
        "Name":["Lokesh","Kadhirvel","Naveen","Razeeth","Arunraj","karthik","Devi","kavitha"],
        "Specialist":["Talking","Comedian","Silent killer","Flirting","Movie scraper","sports","Smily girl","Bold"]
    }
)

# %%
my_team
# Out:
#         Name     Specialist
# 0     Lokesh        Talking
# 1  Kadhirvel       Comedian
# 2     Naveen  Silent killer
# 3    Razeeth       Flirting
# 4    Arunraj  Movie scraper
# 5    karthik         sports
# 6       Devi     Smily girl
# 7    kavitha           Bold
