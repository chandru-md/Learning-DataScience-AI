# %% [markdown]
# ### IMPORT NECESSARY LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as pl

# %%
pd.read

# %% [markdown]
# ### UNIVARIATE ANALYSIS
