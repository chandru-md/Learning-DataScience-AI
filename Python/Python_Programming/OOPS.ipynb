# %%
import Pandas_Math as pdm

# %%
pdm.division(45,5)
# Out:
# 9.0

# %%
pdm.addition(45,5)
# Out:
# 50

# %% [markdown]
# ### OOPS

# %% [markdown]
# #### WITHOUT OOPS

# %%
# DEFINING A FUNCTION
def login(user):
    print(f"{user['name']} has logged in")

def view_task(user):
    print(f"{user['name']} is viewing the task")

def submit_task(user):
    if user['role'] == "Software Engineer": 
        print(f"{user['name']} has submitted the task")
    else:
        print(f"Managers no need to submit the tasks")
def assign_task(user):
    if user['role'] == "Team Lead":
        print(f"{user['name']} has assigned the task")
    else:
        print(f"Team Members can't assign the tasks")



# DATA  COLLECTION
user = {"name":"Lokesh", "role":"Team Lead"}

# FUNCTION TO BE CALLED
login(user)
view_task(user)
submit_task(user)
assign_task(user)
# Out:
# Lokesh has logged in
# Lokesh is viewing the task
# Managers no need to submit the tasks
# Lokesh has assigned the task

# %%
# DEFINING A FUNCTION
def login(user):
    print(f"{user['name']} has logged in")

def view_task(user):
    print(f"{user['name']} is viewing the task")

def submit_task(user):
    if user['role'] == "Software Engineer": 
        print(f"{user['name']} has submitted the task")
    else:
        print(f"Managers no need to submit the tasks")
def assign_task(user):
    if user['role'] == "CEO":
        print(f"{user['name']} has assigned the task")
    else:
        print(f"Team Members can't assign the tasks")



# DATA  COLLECTION
user = {
    "name":"Chandru","role":"Software Engineer"
}

# FUNCTION TO BE CALLED
login(user)
view_task(user)
submit_task(user)
assign_task(user)
# Out:
# Chandru has logged in
# Chandru is viewing the task
# Chandru has submitted the task
# Team Members can't assign the tasks

# %% [markdown]
# #### WITH OOPS

# %% [markdown]
# #### HOW TO CREATE CLASS AND OBJECTS

# %%
class BankAccount:
    
    def __init__(self,name,account_number,balance,pin):
        self.name = name
        self.account_number = account_number
        self.balance = balance
        self.__pin = pin

    def check_balance(self):
        return self.balance

    def deposit(self,amount):
        self.balance = self.balance + amount
        return f"Rs.{amount} deposited Successfully"

    def withdrawal(self,amount,entered_pin):
        if entered_pin != self.__pin:
            print("Incorrect Pin")

        if amount > self.balance:
            print("Insufficient Balance")

        self.balance = self.balance - amount

        return "withdrawn Successfully"

# %%
account1 = BankAccount("Chandru", 12345, 100000, 4321)

#print(account1.check_balance())
#print(account1.deposit(2000))
#print(account1.withdraw(3000, 4321))
#print(account1.check_balance())


account2 = BankAccount("Kadhirvel", 12346, 100000, 7485)

#print(account2.check_balance())
#print(account2.deposit(2000))
#print(account2.withdraw(3000, 7485))
#print(account2.check_balance())

account3 = BankAccount("Razeeth", 12347, 1000000, 9865)

#print(account3.check_balance())
#print(account3.deposit(2000))
#print(account3.withdraw(3000, 9865))
#print(account3.check_balance())

account4 = BankAccount("Karthik", 12348, 10000000, 2365)

#print(account4.check_balance())
#print(account4.deposit(2000))
#print(account4.withdraw(3000, 2365))
#print(account4.check_balance())

account5 = BankAccount("Naveen", 12349, 10000000, 1254)

#print(account5.check_balance())
#print(account5.deposit(2000))
#print(account5.withdraw(3000, 1254))
#print(account5.check_balance())

# %%
account1.balance
# Out:
# 100000

# %%
class ATM:
    
    def __init__(self, account):
        self.account = account

    def show_menu(self):
        print("\n1. Check Balance")
        print("2. Deposit")
        print("3. Withdraw")

    def perform_action(self, choice):
        
        if choice == 1:
            print("Balance:", self.account.check_balance())

        elif choice == 2:
            amount = float(input("Enter amount: "))
            print(self.account.deposit(amount))

        elif choice == 3:
            amount = float(input("Enter amount: "))
            pin = int(input("Enter PIN: "))
            print(self.account.withdraw(amount, pin))

        else:
            print("Invalid choice.")
