# %% [markdown]
# #### cleaning

# %%
# challenge

# %%
data = "968-Maria ( D@t@ Engineer ) ;; 27y  "

# %%
data = data.strip()
print(data)
# Out:
# 968-Maria ( D@t@ Engineer ) ;; 27y

# %%
data = data.replace('@','a')
data
# Out:
# '968-Maria ( Data Engineer ) ;; 27y'

# %%
data = data.replace('968','').replace(';','').replace('-','').replace('(','').replace(')','')

# %%
data
# Out:
# 'Maria  Data Engineer   27y'

# %%
data
# Out:
# 'Maria  Data Engineer   27y'

# %%
name = data[0:5]

# %%
print(name)
# Out:
# Maria

# %%
role = data[7:20]

# %%
print(role)
# Out:
# Data Engineer

# %%
age = data[23:26]

# %%
age
# Out:
# '27y'

# %%
print(f"name:{name} | role:{role} | age:{age}")
# Out:
# name:Maria | role:Data Engineer | age:27y

# %% [markdown]
# #### search

# %%
date = "2026-Feb-10"

# %%
date.startswith('2026')
# Out:
# True

# %%
date.endswith('10')
# Out:
# True

# %%
'Feb' in date
# Out:
# True

# %%
date.find("Feb")
# Out:
# 5

# %%
phone = '+91-95977441105'
print(phone.startswith('+91'))
# Out:
# True

# %%
mail = "chandru@gmail.com"
mail.endswith(".com")
# Out:
# True

# %%
mail = "chandru@yahoo.com"
mail.endswith("gmail.com")
# Out:
# False

# %%
print('@' in mail)
# Out:
# True

# %%
url = "https://api.company.com/v1/data"
print('api'in url)
# Out:
# True

# %%
p1 = '+91-9442389447'
p2 = '9865603219'

# %%
print(p1[4:])
print(p2[:])
# Out:
# 9442389447
# 9865603219

# %%
p1.find('-')
# Out:
# 3

# %%
print(p1[p1.find('-')+1:])
# Out:
# 9442389447

# %%
print(p2[p2.find('-')+1:])
# Out:
# 9865603219

# %% [markdown]
# #### validation

# %%
country = "India"
country.isalpha()
# Out:
# True

# %%
country = 'India 48'
print(country.isalpha())
# Out:
# False

# %%
print(country.isalnum())
# Out:
# False

# %%
print(p1.isnumeric())
# Out:
# False

# %%
print(p2.isnumeric())
# Out:
# True

# %%
print(p1.isalnum())
# Out:
# False

# %% [markdown]
# #### Numbers

# %%
num1 = 5 # int
num2 = 3.09 # float
num3 = 4+6j #advanced math and science
num4 = True # boolean

# %%
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>

# %%
x = 5
y = 5.76
z = 4 + 5j
v = True

# %%
x = str(5)

# %%
type(x)
# Out:
# str

# %%
x = int(x)

# %%
type(x)
# Out:
# int

# %%
print(2-10)
# Out:
# -8

# %%
print(abs(2-10))
# Out:
# 8

# %%
print(22/7)
# Out:
# 3.142857142857143

# %%
print(round(22/7,3))
# Out:
# 3.143

# %%
num = 3.142857142857143
print(round(num))
# Out:
# 3

# %%
import math
math.floor(num)
# Out:
# 3

# %%
math.ceil(num)
# Out:
# 4

# %%
math.trunc(num)
# Out:
# 3

# %%
num = 22/4

# %%
num
# Out:
# 5.5

# %%
math.trunc(num)
# Out:
# 5

# %%
import random
print(random.random())
# Out:
# 0.42527633283982247

# %%
print(random.randint(1,6))
# Out:
# 5

# %%
3.142857142857143
# Out:
# 3.142857142857143

# %%
num = 7.0
num.is_integer()
# Out:
# True

# %%
num = 7.10
num.is_integer()
# Out:
# False

# %%
x = 90
isinstance(x,int)
# Out:
# True

# %%
x = 90
isinstance(x,float)
# Out:
# False

# %%
x = 90.80
isinstance(x,float)
# Out:
# True

# %%
import random
number = random.randint(1,100)
if number %2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# #### Boolean

# %%
print(True)
print(False)
print(type(True))
print(bool(123))
print(bool("Hi"))
print(bool())
# Out:
# True
# False
# <class 'bool'>
# True
# True
# False

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(""))
# Out:
# False

# %%
print(bool(None))
# Out:
# False

# %%
email = ""
phone = "91-9578687550"
username = ""

any([email,phone,username])
# Out:
# True

# %%
email = ""
phone = ""
username = ""

any([email,phone,username])
# Out:
# False

# %%
email = "chandrumd2071@gmail.com"
phone = "+91-9442389447"
username = "chandru_md"

all([email,phone,username])
# Out:
# True

# %%
email = "chandrumd2071@gmail.com"
phone = ""
username = "chandru_md"

all([email,phone,username])
# Out:
# False

# %%
isinstance(123,int)
# Out:
# True

# %%
isinstance(4.13,float)
# Out:
# True

# %%
isinstance(True,str)
# Out:
# False

# %% [markdown]
# #### Comparison Operators

# %%
3>2
# Out:
# True

# %%
2>3
# Out:
# False

# %%
4==5
# Out:
# False

# %%
5==5
# Out:
# True

# %%
4!=5
# Out:
# True

# %%
4>=5
# Out:
# False

# %%
x=90
x>50
# Out:
# True

# %%
print(20 == 20)
print(20!=20)
# Out:
# True
# False

# %%
print(7>=7)
# Out:
# True

# %%
print('a'<'b')
# Out:
# True

# %%
print('a'=='A')
# Out:
# False

# %%
print(5<7<9)
# Out:
# True

# %%
print(5<4<6)
# Out:
# False

# %%
print(3>1 and 5<1)
# Out:
# False

# %%
print(3>1 and 4<6)
# Out:
# True

# %%
print(3>1 or 5<1)
# Out:
# True

# %%
x =not True
print(x)
# Out:
# False

# %%
is_logged_in = True
is_guest = False
is_banned = False

print(is_logged_in or is_guest and not is_banned)
# Out:
# True

# %%
is_logged_in = True
is_guest = False
is_banned = True

print((is_logged_in or is_guest) and not is_banned)
# Out:
# False

# %%
'a' in 'chandru'
# Out:
# True

# %%
'a' in 'apple'
# Out:
# True

# %%
'a' not in 'data'
# Out:
# False

# %%
'chandru' in ['raz','kad','nav']
# Out:
# False

# %%
'chandru' not in ['raz','kad','nav']
# Out:
# True

# %%
a = [1,2,3,4,5]
b = [1,2,3,4,5]

# %%
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
user_name = ""
age = 17
print(username is not None and age >18)
# Out:
# False

# %%
password = "Chandru"
print(password)
