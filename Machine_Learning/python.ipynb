# %% [markdown]
# ### Conditional Statements

# %% [markdown]
# #### Standalone - if

# %%
age = 18
if age > 18:
    print("You're eligible to vote")

# %%
age = 19 
if age > 18:
    print("Your are allowed to drive.")
# Out:
# Your are allowed to drive.

# %%
score = 100
if score >= 90:
    print("Your are Good")
# Out:
# Your are Good
